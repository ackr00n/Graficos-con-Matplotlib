# %%
import pandas as pd
import matplotlib.pyplot as plt

datos = pd.read_csv("productos.csv")
df =datos[["unitsInStock", "categoryID"]]
df.head(25).plot.barh(x="unitsInStock",y="categoryID")
plt.show()

# %%
import pandas as pd

datos = pd.read_csv("productos.csv")

df = datos[["categoryID" ]]



df.categoryID.value_counts().plot.pie()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

datos = pd.read_csv("productos.csv")
df = [["productID","unitPrice"]]
plt.hist(df)

plt.xlabel("productID")
plt.ylabel("unitPrice")

plt.show()
